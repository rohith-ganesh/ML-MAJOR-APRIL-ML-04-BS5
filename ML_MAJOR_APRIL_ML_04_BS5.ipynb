# %% [markdown]
# <a href="https://colab.research.google.com/github/rohith-ganesh/ML-MAJOR-APRIL-ML-04-BS5/blob/main/ML_MAJOR_APRIL_ML_04_BS5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vadersentiment
# Out:
# Collecting vadersentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 3.1MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vadersentiment) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (2.10)
# Installing collected packages: vadersentiment
# Successfully installed vadersentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

# %%
text ='this is very good'
vs.polarity_scores(text)
# Out:
# {'compound': 0.4927, 'neg': 0.0, 'neu': 0.484, 'pos': 0.516}

# %%
#web scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
url ='https://inshorts.com/en/read/sports'
news_data=[]  
news_category = url.split('/')[-1]
data = requests.get(url)
soup = BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="manifest.json" rel="manifest"/>
# <!-- Fallback to homescreen for Chrome   <39 on Android -->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="inshorts" name="application-name"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
# <!-- Add to homescreen for Safari on iOS -->
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="inshorts" name="apple-mobile-web-app-title"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
# <!-- Tile icon for Win8 (144x144 + tile color) -->
# <meta content="fav/favicon.png" name="msapplication-TileImage"/>
# <meta content="#424242" name="msapplication-TileColor"/>
# <meta content="#424242" name="theme-color"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="#424242" name="msapplication-navbutton-color"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="app" name="twitter:card"/>
# <meta content="@inshorts" name="twitter:site"/>
# <meta content="@inshorts" name="twitter:creator"/>
# <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description"/>
# <meta content="IN" name="twitter:app:country"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone"/>
# <meta content="892146527" name="twitter:app:id:iphone"/>
# <meta content="nis://news" name="twitter:app:url:iphone"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad"/>
# <meta content="892146527" name="twitter:app:id:ipad"/>
# <meta content="nis://news" name="twitter:app:url:ipad"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
# <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
# <meta content="nis://news" name="twitter:app:url:googleplay"/>
# <meta content="Read sports news in English in less that 60 words and get updated with latest cricket, football, tennis and basketball in a fast and easy way with inshorts." name="description"/>
# <link href="https://inshorts.com/en/read/sports" rel="canonical"/>
# <link href="https://inshorts.com/en/read/sports" reflang="en" rel="alternate"/>
# <meta content="app-id=892146527" name="apple-itunes-app"/>
# <meta content="app-id=com.nis.app" name="google-play-app"/>
# <title>Sports News: Cricket News, Football News &amp; Tennis News in English with Inshorts</title>
# <!-- CSS  -->
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png"/>
# <link href="/dist/manifest.json" rel="manifest"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#   </script>
# <!-- Top banner for desktop-->
# <script>
#     googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Mix panel script start -->
# <script>
#   (function(f,b){if(!b.__SV){var e,g,i,h;window.mixpanel=b;b._i=[];b.init=function(e,f,c){function g(a,d){var b=d.split(".");2==b.length&&(a=a[b[0]],d=b[1]);a[d]=function(){a.push([d].concat(Array.prototype.slice.call(arguments,0)))}}var a=b;"undefined"!==typeof c?a=b[c]=[]:c="mixpanel";a.people=a.people||[];a.toString=function(a){var d="mixpanel";"mixpanel"!==c&&(d+="."+c);a||(d+=" (stub)");return d};a.people.toString=function(){return a.toString(1)+".people (stub)"};i="disable time_event track track_pageview track_links track_forms track_with_groups add_group set_group remove_group register register_once alias unregister identify name_tag set_config reset opt_in_tracking opt_out_tracking has_opted_in_tracking has_opted_out_tracking clear_opt_in_out_tracking start_batch_senders people.set people.set_once people.unset people.increment people.append people.union people.track_charge people.clear_charges people.delete_user people.remove".split(" ");
#   for(h=0;h<i.length;h++)g(a,i[h]);var j="set set_once union unset remove delete".split(" ");a.get_group=function(){function b(c){d[c]=function(){call2_args=arguments;call2=[c].concat(Array.prototype.slice.call(call2_args,0));a.push([e,call2])}}for(var d={},e=["get_group"].concat(Array.prototype.slice.call(arguments,0)),c=0;c<j.length;c++)b(j[c]);return d};b._i.push([e,f,c])};b.__SV=1.2;e=f.createElement("script");e.type="text/javascript";e.async=!0;e.src="undefined"!==typeof MIXPANEL_CUSTOM_LIB_URL?
#   MIXPANEL_CUSTOM_LIB_URL:"file:"===f.location.protocol&&"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js".match(/^\/\//)?"https://cdn.mxpnl.com/libs/mixpanel-2-latest.min.js":"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js";g=f.getElementsByTagName("script")[0];g.parentNode.insertBefore(e,g)}})(document,window.mixpanel||[]);
#   mixpanel.init("a99a1037068944b00a0cc8ee56c94e8c")
#   mixpanel.track("pageview")
#   </script>
# <!-- Mix panel script end -->
# </head>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
# </script>
# <!-- Add After importing GA and Mixpanel scripts -->
# <script>
#   function track_GA_Mixpanel({hitType, category, action, label, value = 1}){
#     if (window && window.ga) {
#       ga('send', {
#             hitType: 'event',
#             eventCategory: category,
#             eventAction: action,
#             eventLabel: label,
#             eventValue: value
#         });
#     }
#     // mix panel analytics
#     if(window && window.mixpanel){
#         mixpanel.track("event", {category, action, label, value});
#     }
#   }
# </script>
# <body>
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- HEADER START -->
# <div class="header z-depth-1">
# <div class="menu clickable">
# <button class="c-hamburger c-hamburger--htx"><span>toggle menu</span></button><span class="unselectable">Menu</span>
# </div>
# <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
# <a href="/"><img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/></a>
# </div>
# <!-- HEADER END -->
# <!--SIDEBAR START -->
# <div class="hide-on-med-and-up sidebar-bg" style="display: none;"> </div>
# <div class="sidebar" style="overflow-y: scroll;">
# <div class="lang-bar" style="">
# <div class="lang-selector clickable">
# <a href="/en/read/sports"><div class="lang-en selected">English</div></a>
# <a href="/hi/read/sports"><div class="lang-hi ">हिन्दी</div></a>
# </div>
# </div>
# <div>
# <div class="category-header">Categories</div>
# <ul class="category-list">
# <a href="/en/read" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToAllNews', 'action': 'clicked', 'label': 'RedirectedToAllNews' });"> <li class="active-category ">All News</li> </a>
# <a href="/en/read/national" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToIndiaNews', 'action': 'clicked', 'label': 'RedirectedToIndiaNews' });"> <li class="active-category ">India</li> </a>
# <a href="/en/read/business" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToBusinessNews', 'action': 'clicked', 'label':  'RedirectedToBusinessNews' });"> <li class="active-category ">Business</li> </a>
# <a href="/en/read/sports" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTosportsNews', 'action': 'clicked', 'label': 'RedirectedToSportsNews' });"> <li class="active-category selected">Sports</li> </a>
# <a href="/en/read/world" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToworldNews', 'action': 'clicked', 'label': 'RedirectedToworldNews' });"> <li class="active-category ">World</li> </a>
# <a href="/en/read/politics" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToworldNews', 'action': 'clicked',   'label': 'RedirectedToworldNews' });"> <li class="active-category ">Politics</li> </a>
# <a href="/en/read/technology" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTotechnologyNews', 'action': 'clicked', 'label': 'RedirectedTotechnologyNews' });"> <li class="active-category ">Technology</li> </a>
# <a href="/en/read/startup" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTostartupNews', 'action': 'clicked', 'label': 'RedirectedTostartupNews' });"> <li class="active-category ">Startup</li> </a>
# <a href="/en/read/entertainment" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToEntertainmentNews', 'action': 'clicked', 'label': 'RedirectedToEntertainmentNews' });"> <li class="active-category ">Entertainment</li> </a>
# <a href="/en/read/miscellaneous" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToMiscellaneousNews', 'action': 'clicked', 'label': 'RedirectedToMiscellaneousNews' });"> <li class="active-category ">Miscellaneous</li> </a>
# <a href="/en/read/hatke" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkTohatkeNews', 'action': 'clicked', 'label': 'RedirectedTohatkeNews' });"> <li class="active-category ">Hatke</li> </a>
# <a href="/en/read/science" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToscienceNews', 'action': 'clicked', 'label': 'RedirectedToscienceNews' });"> <li class="active-category ">Science</li> </a>
# <a href="/en/read/automobile" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToautomobileNews', 'action': 'clicked', 'label': 'RedirectedToautomobileNews' });"> <li class="active-category ">Automobile</li> </a>
# </ul>
# </div>
# </div>
# <!--SIDEBAR END -->
# <!-- BODY START -->
# <div class="container" style="min-height:550px;">
# <div class="row" style="padding-top:110px;">
# <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
# <script>
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#           </script>
# </div>
# <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
# <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#           For the best experience use <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#         </div>
# </div>
# <div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/manjrekars-chat-with-twitter-user-goes-viral-says-jadeja-doesnt-know-english-1623209755267" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="Manjrekar's chat with Twitter user goes viral, says 'Jadeja doesn't know English'" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/9_wed/img_1623209215832_562.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/9_wed/img_1623209215832_562.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/manjrekars-chat-with-twitter-user-goes-viral-says-jadeja-doesnt-know-english-1623209755267" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'Manjrekar's%20chat%20with%20Twitter%20user%20goes%20viral%2C%20says%20'Jadeja%20doesn't%20know%20English')' });" style="color:#44444d!important">
# <span itemprop="headline">Manjrekar's chat with Twitter user goes viral, says 'Jadeja doesn't know English'</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/manjrekars-chat-with-twitter-user-goes-viral-says-jadeja-doesnt-know-english-1623209755267"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-06-09T03:35:55.000Z" itemprop="datePublished">09:05 am</span> on <span clas="date">09 Jun 2021,Wednesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">A Twitter user shared screenshots of his personal chat with commentator Sanjay Manjrekar, wherein the duo can be seen debating about Manjrekar's opinion about Ravindra Jadeja and Ravichandran Ashwin. Referring to controversy over him calling Jadeja a 'bits and pieces' player, Manjrekar, in the chat said, "Jadeja doesn't know English...so he didn't know the actual meaning of bits and pieces."</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/manjrekars-chat-with-twitter-user-goes-viral-says-jadeja-doesnt-know-english-1623209755267"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-06-09T03:35:55.000Z" itemprop="dateModified">09:05 am</span> on <span class="date">09 Jun</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/jadeja-doesnt-know-english-a-twitter-user-leaks-his-dm-conversation-with-sanjay-manjrekar/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/we-were-bloody-indians-to-them-now-they-lick-our-backsides-engineer-on-racism-in-uk-1623244851707" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="We were 'bloody Indians' to them, now they lick our backsides: Engineer on racism in UK" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/9_wed/img_1623243276175_671.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/9_wed/img_1623243276175_671.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/we-were-bloody-indians-to-them-now-they-lick-our-backsides-engineer-on-racism-in-uk-1623244851707" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'We%20were%20'bloody%20Indians'%20to%20them%2C%20now%20they%20lick%20our%20backsides%3A%20Engineer%20on%20racism%20in%20UK)' });" style="color:#44444d!important">
# <span itemprop="headline">We were 'bloody Indians' to them, now they lick our backsides: Engineer on racism in UK</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/we-were-bloody-indians-to-them-now-they-lick-our-backsides-engineer-on-racism-in-uk-1623244851707"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-06-09T13:20:51.000Z" itemprop="datePublished">06:50 pm</span> on <span clas="date">09 Jun 2021,Wednesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Referring to racism he faced in England years ago, ex-India wicketkeeper-batsman Farokh Engineer said people used to make fun of his accent. "We were all 'bloody Indians' to them till a few years ago. Now once...IPL started, they're all licking our backsides," he added. "It amazes me that just because of money, they are licking our boots now," Farokh stated. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/we-were-bloody-indians-to-them-now-they-lick-our-backsides-engineer-on-racism-in-uk-1623244851707"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-06-09
amp.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'Hindustan%20Times' });" target="_blank">Hindustan Times</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/graph-is-little-up-and-down-but-rahane-always-steps-up-exselector-prasad-1623169569830" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Ankur Taliyan" itemprop="name"></span>
# </span>
# <span content="Graph is little up and down, but Rahane always steps up: Ex-selector Prasad" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/8_tue/img_1623166265976_250.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/8_tue/img_1623166265976_250.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/graph-is-little-up-and-down-but-rahane-always-steps-up-exselector-prasad-1623169569830" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'Graph%20is%20little%20up%20and%20down%2C%20but%20Rahane%20always%20steps%20up%3A%20Ex-selector%20Prasad)' });" style="color:#44444d!important">
# <span itemprop="headline">Graph is little up and down, but Rahane always steps up: Ex-selector Prasad</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/graph-is-little-up-and-down-but-rahane-always-steps-up-exselector-prasad-1623169569830"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-06-08T16:26:09.000Z" itemprop="datePublished">09:56 pm</span> on <span clas="date">08 Jun 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Talking about Ajinkya Rahane's form, former Team India chief selector MSK Prasad said that while the "graph is a little up and down", Rahane always rises to the occasion when the team is in trouble. "Rahane is a proven player and his overseas record is far superior to many...We should not be putting unnecessary pressure on him," he added. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/graph-is-little-up-and-down-but-rahane-always-steps-up-exselector-prasad-1623169569830"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-06-08T16:26:09.000Z" itemprop="dateModified">09:56 pm</span> on <span class="date">08 Jun</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/whenever-virat-hasnt-played-big-innings-this-man-has-stepped-up-msk-prasad-lauds-ajinkya-rahanes-contribution-in-the-indian-team/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'ReadMore', 'action': 'clicked', 'label': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/indias-campaign-ends-with-bopannaskugor-loss-in-french-open-quarters-1623153837563" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anant Kaur" itemprop="name"></span>
# </span>
# <span content="India's campaign ends with Bopanna-Skugor loss in French Open quarters" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/8_tue/img_1623135538278_238.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/06_jun/8_tue/img_1623135538278_238.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/indias-campaign-ends-with-bopannaskugor-loss-in-french-open-quarters-1623153837563" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'TitleOfNews', 'action': 'clicked', 'label': 'India's%20campaign%20ends%20with%20Bopanna-Skugor%20loss%20in%20French%20Open%20quarters)' });" style="color:#44444d!important">
# <span itemprop="headline">India's campaign ends with Bopanna-Skugor loss in French Open quarters</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/indias-campaign-ends-with-bopannaskugor-loss-in-french-open-quarters-1623153837563"><span class="short">short</span></a> by <span class="author">Anant Kaur</span> /
#       <span class="time" content="2021-06-08T12:03:57.000Z" itemprop="datePublished">05:33 pm</span> on <span clas="date">08 Jun 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Indian tennis player Rohan Bopanna and his Croatian partner Franko Skugor lost 5-7, 3-6 to the Spanish pair of Pablo Andujar and Pedro Martinez in the men's doubles quarter-finals at the French Open on Monday. The unseeded Indo-Croatian pair had received a walkover in the third round on Sunday against Netherlands' Matwe Middelkoop and Marcelo Arevalo of El Salvador.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/indias-campaign-ends-with-bopannaskugor-loss-in-french-open-quarters-1623153837563"><span class="short">short</span></a> by <span class="author">Anant Kaur</span> /
#       <span class="time" content="2021-06-08T12:03:57.000Z" itemprop="dateModified">05:33 pm</span> on <span class="date">08 Jun</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="load-more-wrapper">
# <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">Load More</div>
# <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;"><img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/></div>
# </div>
# <div class="my-red app-download-pane hide-on-large-only">
# <div class="container">
# <div class="row">
# <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#               For the best experience use <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- BODY END -->
# <footer class="page-footer teals">
# <div class="container">
# <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
# <div class="col offset-l3 l3 m4 s12 right social-admin">
# <div class="social-share"><a href="https://www.facebook.com/inshortsapp" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToFaceBookPage', 'action': 'clicked', 'label': 'RedirectedToFaceBook' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/facebook.png"/></a></div>
# <div class="social-share"><a href="https://twitter.com/inshorts" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToTwitterPage', 'action': 'clicked', 'label': 'RedirectedToTwitter' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/twitter.png"/></a></div>
# <div class="social-share"><a href="https://www.linkedin.com/company/news-in-shorts" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToLinkedinPage', 'action': 'clicked', 'label': 'RedirectedToLinkedin' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/></a></div>
# </div>
# <div class="col m4 l3 s6 footer-left-pane">
# <div class="right"><img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/></div>
# <div class="copy-text">
# <span><span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">inshorts</span> medialabs pvt. ltd.</span><br/>
#           ©<span style="font-size:12px">COPYRIGHT 2021</span>
# </div>
# </div>
# <div class="col m4 l3 s6 footer-right-pane">
# <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;"><img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/></div>
# <div class="terms-text">
# <a class="tnc" href="/tnc" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToTermsAndConditionsAndPP', 'action': 'clicked', 'label': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank"><span>Terms &amp; conditions</span><br/>
# <span>Privacy Policies</span>
# </a>
# <br/>
# <a class="tnc" href="/editorial_policy" onclick="track_GA_Mixpanel({'hitType': 'event', 'category': 'LinkToSitemap', 'action': 'clicked', 'label': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
# <span>Editorial Policy</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal_contact row" id="contactUsModal">
# <!-- Modal content -->
# <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
# <span class="close">×</span>
# <div class="contact">
# <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Hiring Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Admin Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Marketing Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Editorial Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Sales Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact For Any Other Query</button>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <script>
# var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
# </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js"></script>
# <script src="/dist/scripts/index.js" type="text/javascript"></script>
# <script src="/dist/scripts/read.js" type="text/javascript"></script>
# <script src="/dist/scripts/jquery.scrolldepth.min.js"></script>
# <script type="text/javascript">
#
#     var min_news_id = "ih85e067-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'sports','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# </body>
# </html>

# %%
urls =['https://inshorts.com/en/read/sports',
      'https://inshorts.com/en/read/world',
      'https://inshorts.com/en/read/politics']
def build_dataset(urls):
  news_data=[]
  for url in urls:
    news_category = url.split('/')[-1]
    data = requests.get(url)
    soup = BeautifulSoup(data.content)
    
    news_articles = [{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                      'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                      'news_category':news_category}
                     for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                                 soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles=news_articles[0:20]
    news_data.extend(news_articles)

  df = pd.DataFrame(news_data)  
  df=df[['news_headline','news_article','news_category']]
  return df

# %%
df = build_dataset(urls)
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  Anything can happen any time: BJP as Pilot sai...  ...      politics
# 56  My priority is public service: Scindia on port...  ...      politics
# 57  He's like my brother: Scindia welcomes ex-Cong...  ...      politics
# 58  Floods have become a norm: AAP criticises BMC ...  ...      politics
# 59  Mamata supports farmers' protest, says bulldoz...  ...      politics
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv('/content/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   Despite all the controversies, Greg Chappell t...  ...        sports
# 1   Manjrekar's chat with Twitter user goes viral,...  ...        sports
# 2   Serbian volleyball player suspended for 'slant...  ...        sports
# 3   Wrestler Sushil asks for protein supplements, ...  ...        sports
# 4   Buttler and Morgan's tweets allegedly mocking ...  ...        sports
# 5   We were 'bloody Indians' to them, now they lic...  ...        sports
# 6   Eng-Pak series not to be broadcast in Pak as I...  ...        sports
# 7   I was expecting to captain India in 2007 T20 W...  ...        sports
# 8   Sometimes, we didn't want to see each other: P...  ...        sports
# 9   Anderson deletes his 11-year-old tweet calling...  ...        sports
# 10  Asiad gold medallist boxer Dingko Singh passes...  ...        sports
# 11  US eases COVID-19 travel warning to Japan ahea...  ...        sports
# 12  We can win a medal in hockey at Tokyo Olympics...  ...        sports
# 13  Ben Stokes likely to return to T20 Blast after...  ...        sports
# 14  Graph is little up and down, but Rahane always...  ...        sports
# 15  People asked me what are we going to do when C...  ...        sports
# 16  Hearing people say Robinson should never play ...  ...        sports
# 17  My form hasn't dipped, it's a matter of a coup...  ...        sports
# 18  I'm backing Pujara to get the highest runs in ...  ...        sports
# 19  Ex-cricketer Carberry criticises UK sports min...  ...        sports
# 20  White House drops Trump's orders that sought t...  ...         world
# 21  Remove him from the country: Dominica as it de...  ...         world
# 22  Herd of elephants spotted sleeping after year-...  ...         world
# 23  Kim Jong-un appears to have lost weight in pic...  ...         world
# 24  Russia holds beauty contest for female prison ...  ...         world
# 25  9 dead as 5-storey building being demolished c...  ...         world
# 26  Cicadas delay flight carrying journalists for ...  ...         world
# 27  US chemist removes COVID vaccine from fridge b...  ...         world
# 28  Nun stole ₹6 crore from school for her casino ...  ...         world
# 29  Nepal halts distribution of Patanjali's Coroni...  ...         world
# 30  EU Parliament approves digital COVID-19 certif...  ...         world
# 31  US to buy 500 mn Pfizer vaccine doses to donat...  ...         world
# 32  US man arrested for allegedly posing as Trump'...  ...         world
# 33  Talking to PM Imran Khan is like conversing wi...  ...         world
# 34  China denounces US bill aimed at boosting comp...  ...         world
# 35  Suu Kyi hit with new corruption charges by Mya...  ...         world
# 36  Man kills 2 sisters after 'deal with demon' to...  ...         world
# 37  Chinese students hold principal hostage for 30...  ...         world
# 38  Biden begins 1st official foreign trip with a ...  ...         world
# 39  Argentine Prez says Brazilians 'came from jung...  ...         world
# 40  Nikhil reacts to Nusrat's statement on 'invali...  ...      politics
# 41  Nikhil illegally took my money, his family kep...  ...      politics
# 42  Nusrat claims her marriage is invalid, says sh...  ...      politics
# 43  MP Cong compares Jitin Prasada to 'garbage', d...  ...      politics
# 44  If girlfriend leaves you for your rival, don't...  ...      politics
# 45  Congress leader Jitin Prasada joins BJP in pre...  ...      politics
# 46  It's been 10 months but party hasn't resolved ...  ...      politics
# 47  Thank you for leaving: Chhattisgarh Cong after...  ...      politics
# 48  It's a murder: BJP's Ram Kadam blames BMC for ...  ...      politics
# 49  27-yr-old BJP worker's dead body found in pond...  ...      politics
# 50  No instability in the BJP govt in MP: Narendra...  ...      politics
# 51  Had detailed discussion with PM on Bengal for ...  ...      politics
# 52  TMC turncoats Mukul Roy, Rajib Banerjee absent...  ...      politics
# 53  It is Congress' loss: Sanjay Jha on Jitin Pras...  ...      politics
# 54  Posters in Bengal claim BJP's Rajib Banerjee i...  ...      politics
# 55  Anything can happen any time: BJP as Pilot sai...  ...      politics
# 56  My priority is public service: Scindia on port...  ...      politics
# 57  He's like my brother: Scindia welcomes ex-Cong...  ...      politics
# 58  Floods have become a norm: AAP criticises BMC ...  ...      politics
# 59  Mamata supports farmers' protest, says bulldoz...  ...      politics
#
# [60 rows x 3 columns]

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 177

# %%
#Remove HTML Tag
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text = soup.get_text()
  return new_text

html_tag('<html><h2> Some important info </h2></html>')
# Out:
# ' Some important info '

# %%
#Expand Contractions
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand

con("Y'all can't expand I'd think")
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.0.49)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.2.0)
# 'you all can not expand I would think'

# %%
import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s]'
  text=re.sub(pattern,'',text)
  return text

remove_sp ("+-*/skdm" )
# Out:
# 'skdm'

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in stopword_list]
  filtered_text=' '.join(filtered_tokens)
  return filtered_text

# %%
remove_stopwords("The, and , if are all stopwords and even not")
# Out:
# 'The , , stopwords even not'

# %%
#1.Lower case
#2.HTML Tags
#3.contractions
#4.special Characters
#5. stop words

df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_article = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)

df.head()
# Out:
#                                        news_headline  ... news_category
# 0  despite controversies greg chappell taught ind...  ...        sports
# 1  manjrekars chat twitter user goes viral says j...  ...        sports
# 2  serbian volleyball player suspended slant eye ...  ...        sports
# 3  wrestler sushil asks protein supplements exerc...  ...        sports
# 4  buttler morgans tweets allegedly mocking india...  ...        sports
#
# [5 rows x 3 columns]

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df
# Out:
#                                         news_headline  ... compound
# 0   despite controversies greg chappell taught ind...  ...   0.5859
# 1   manjrekars chat twitter user goes viral says j...  ...   0.3400
# 2   serbian volleyball player suspended slant eye ...  ...  -0.7351
# 3   wrestler sushil asks protein supplements exerc...  ...  -0.7003
# 4   buttler morgans tweets allegedly mocking india...  ...   0.7096
# 5    bloody indians lick backsides engineer racism uk  ...  -0.1280
# 6   engpak series not broadcast pak indian company...  ...  -0.4576
# 7   expecting captain india 2007 t20 world cup yuv...  ...   0.1531
# 8   sometimes not want see prasad arguments kohli ...  ...   0.5687
# 9   anderson deletes 11yearold tweet calling broad...  ...   0.5994
# 10  asiad gold medallist boxer dingko singh passes...  ...  -0.3182
# 11  us eases covid19 travel warning japan ahead ol...  ...   0.4939
# 12  win medal hockey tokyo olympics goalkeeper pathak  ...   0.9432
# 13         ben stokes likely return t20 blast 3 years  ...  -0.4588
# 14  graph little rahane always steps exselector pr...  ...   0.3995
# 15    people asked going chhetri retires coach stimac  ...   0.2960
# 16  hearing people say robinson never play ridicul...  ...  -0.2634
# 17       form not dipped matter couple matches chahal  ...  -0.0516
# 18  I backing pujara get highest runs wtc final pa...  ...   0.0772
# 19  excricketer carberry criticises uk sports mini...  ...  -0.5286
# 20  white house drops trumps orders sought ban tik...  ...  -0.2960
# 21  remove country dominica declares choksi prohib...  ...   0.0516
# 22  herd elephants spotted sleeping yearlong 500km...  ...  -0.5994
# 23  kim jongun appears lost weight pictures releas...  ...  -0.3182
# 24  russia holds beauty contest female prison offi...  ...   0.5719
# 25  9 dead 5storey building demolished collapses b...  ...  -0.9564
# 26  cicadas delay flight carrying journalists bide...  ...  -0.2263
# 27  us chemist removes covid vaccine fridge believ...  ...  -0.7845
# 28  nun stole 6 crore school casino gambling expen...  ...  -0.6124
# 29  nepal halts distribution patanjalis coronil ki...  ...   0.6575
# 30  eu parliament approves digital covid19 certifi...  ...   0.0258
# 31  us buy 500 mn pfizer vaccine doses donate glob...  ...   0.2960
# 32  us man arrested allegedly posing trumps family...  ...  -0.8779
# 33  talking pm imran khan like conversing deaf sin...  ...  -0.4939
# 34  china denounces us bill aimed boosting competi...  ...  -0.0516
# 35  suu kyi hit new corruption charges myanmar aut...  ...  -0.5106
# 36      man kills 2 sisters deal demon win lottery uk  ...  -0.8658
# 37  chinese students hold principal hostage 30 hrs...  ...  -0.5859
# 38  biden begins 1st official foreign trip warning...  ...   0.7552
# 39  argentine prez says brazilians came jungle get...  ...  -0.3400
# 40  nikhil reacts nusrats statement invalid marria...  ...  -0.0872
# 41  nikhil illegally took money family kept jewell...  ...   0.6486
# 42  nusrat claims marriage invalid says separated ...  ...   0.4019
# 43  mp cong compares jitin prasada garbage deletes...  ...   0.8360
# 44  girlfriend leaves rival not blame jha jitin jo...  ...   0.8093
# 45  congress leader jitin prasada joins bjp presen...  ...   0.6597
# 46  10 months party not resolved raj cong mlas iss...  ...  -0.5883
# 47  thank leaving chhattisgarh cong jitin prasada ...  ...   0.8910
# 48  murder bjps ram kadam blames bmc building coll...  ...  -0.6379
# 49        27yrold bjp workers dead body found pond wb  ...  -0.3400
# 50    no instability bjp govt mp narendra singh tomar  ...   0.3384
# 51   detailed discussion pm bengal 45 minutes suvendu  ...   0.8779
# 52  tmc turncoats mukul roy rajib banerjee absent ...  ...   0.4019
# 53  congress loss sanjay jha jitin prasada joining...  ...   0.6742
# 54  posters bengal claim bjps rajib banerjee not w...  ...   0.1265
# 55  anything happen time bjp pilot said issues not...  ...   0.6917
# 56  priority public service scindia portfolio unio...  ...   0.0000
# 57  like brother scindia welcomes excong leader pr...  ...   0.9022
# 58  floods become norm aap criticises bmc mumbai r...  ...   0.1280
# 59  mamata supports farmers protest says bulldozin...  ...   0.2008
#
# [60 rows x 4 columns]

# %%
# Out:
# 3
